# %%
import numpy as np
import pandas as pd

# %%
RW=pd.read_csv(r"C:\Users\harsh\Downloads\Kaggel Dataset Python Final Capstone\winequality-red.csv")

# %%
RW
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print(RW.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print(RW.isnull().any().any())
# Out:
# False

# %%
RW.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
Target = RW['quality']

# %%
Feature = RW[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]

# %%
import sklearn

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaling = MinMaxScaler()

# %%
scaling.fit_transform(Feature[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']])
# Out:
# array([[0.24778761, 0.39726027, 0.        , ..., 0.60629921, 0.13772455,
#         0.15384615],
#        [0.28318584, 0.52054795, 0.        , ..., 0.36220472, 0.20958084,
#         0.21538462],
#        [0.28318584, 0.43835616, 0.04      , ..., 0.40944882, 0.19161677,
#         0.21538462],
#        ...,
#        [0.15044248, 0.26712329, 0.13      , ..., 0.53543307, 0.25149701,
#         0.4       ],
#        [0.11504425, 0.35958904, 0.12      , ..., 0.65354331, 0.22754491,
#         0.27692308],
#        [0.12389381, 0.13013699, 0.47      , ..., 0.51181102, 0.19760479,
#         0.4       ]])

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Feature,Target, test_size=0.2)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1110            8.3             0.530         0.00             1.4      0.070
# 814            12.6             0.410         0.54             2.8      0.103
# 578             8.8             0.470         0.49             2.9      0.085
# 391            13.7             0.415         0.68             2.9      0.085
# 1469            7.3             0.980         0.05             2.1      0.061
# ...             ...               ...          ...             ...        ...
# 142             5.2             0.340         0.00             1.8      0.050
# 1343            7.5             0.510         0.02             1.7      0.084
# 445             9.5             0.735         0.10             2.1      0.079
# 458            10.4             0.330         0.63             2.8      0.084
# 1542            6.7             0.855         0.02             1.9      0.064
#
# ...

# %%
X_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 248             7.7             0.530         0.06             1.7      0.074
# 774             7.9             0.400         0.30             1.8      0.157
# 1220           10.9             0.320         0.52             1.8      0.132
# 186             7.4             0.390         0.48             2.0      0.082
# 647             8.3             0.845         0.01             2.2      0.070
# ...             ...               ...          ...             ...        ...
# 183             6.8             0.610         0.20             1.8      0.077
# 335            11.9             0.695         0.53             3.4      0.128
# 1403            7.2             0.330         0.33             1.7      0.061
# 615             9.6             0.600         0.50             2.3      0.079
# 175             6.9             0.500         0.04             1.5      0.085
#
# ...

# %%
y_train
# Out:
# 1110    6
# 814     6
# 578     5
# 391     6
# 1469    3
#        ..
# 142     6
# 1343    6
# 445     6
# 458     7
# 1542    6
# Name: quality, Length: 1279, dtype: int64

# %%
y_test
# Out:
# 248     6
# 774     6
# 1220    6
# 186     5
# 647     4
#        ..
# 183     5
# 335     7
# 1403    8
# 615     5
# 175     5
# Name: quality, Length: 320, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
CLFLR = LinearRegression()

# %%
CLFLR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
CLFLR.predict(X_test)
# Out:
# array([5.32222643, 5.57095239, 6.18402716, 5.21139099, 5.5187225 ,
#        5.52102488, 5.77892497, 5.31660429, 5.51635193, 5.52104934,
#        6.09640486, 6.58522163, 5.42626414, 5.84670565, 5.71487513,
#        5.4493117 , 5.87496898, 5.38679571, 5.21995315, 5.82261206,
#        6.27371944, 5.01293927, 4.93084752, 6.16415887, 5.94163542,
#        5.20372724, 5.72024545, 5.72578536, 5.61145782, 4.76352092,
#        5.32307652, 5.86295941, 5.91558299, 5.44071877, 5.87565992,
#        5.19320754, 6.75387373, 6.76452143, 6.49202653, 4.94827458,
#        5.30759901, 5.81841935, 5.0849234 , 5.15743241, 5.55330872,
#        4.66798706, 5.96755995, 6.517383  , 4.95093859, 5.76412876,
#        5.28208287, 4.80044383, 4.70825743, 5.18737788, 6.02986922,
#        5.10720012, 5.39434703, 5.2316288 , 6.59569625, 6.32302156,
#        6.17308417, 6.40090303, 5.39816686, 5.41207773, 5.67278867,
#        6.47877049, 5.4425339 , 5.36042197, 5.62302069, 5.68967063,
# ...

# %%
y_test
# Out:
# 248     6
# 774     6
# 1220    6
# 186     5
# 647     4
#        ..
# 183     5
# 335     7
# 1403    8
# 615     5
# 175     5
# Name: quality, Length: 320, dtype: int64

# %%
CLFLR.score(X_test,y_test)
# Out:
# 0.3023777178986765

# %%
from sklearn.metrics import mean_squared_error
y_train
# Out:
# 1110    6
# 814     6
# 578     5
# 391     6
# 1469    3
#        ..
# 142     6
# 1343    6
# 445     6
# 458     7
# 1542    6
# Name: quality, Length: 1279, dtype: int64

# %%
MSEOD = mean_squared_error(CLFLR.predict(X_test),y_test)
print("Mean squared error:", MSEOD)
# Out:
# Mean squared error: 0.4048866196051148

# %%
from sklearn.metrics import r2_score

# %%
RSQES = r2_score(CLFLR.predict(X_test),y_test)
print("R squared error:", RSQES)
# Out:
# R squared error: -0.7486743298883283
